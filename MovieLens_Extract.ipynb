# %%
import pandas as pd

# %%
file_dir = "C:/Users/annab/ucb/Movies-ETL"

# %%
kaggle_metadata = pd.read_csv(f"{file_dir}/movies_metadata.csv", low_memory=False)
ratings = pd.read_csv(f"{file_dir}/ratings.csv")

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 20559  False                                                NaN        0
# 42341  False                                                NaN        0
# 28573  False                                                NaN  6400000
# 42849  False                                                NaN        0
# 39824  False  {'id': 24717, 'name': 'Johan Falk GSI Collecti...        0
#
#                                                   genres  \
# 20559  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 42341  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 28573  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 42849                      [{'id': 18, 'name': 'Drama'}]
# 39824  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                     homepage      id    imdb_id  \
# 20559                                    NaN   42455  tt0069715
# ...
